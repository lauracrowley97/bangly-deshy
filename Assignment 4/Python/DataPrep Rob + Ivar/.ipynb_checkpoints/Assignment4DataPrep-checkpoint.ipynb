# %%
import pandas as pd
pd.options.display.max_columns = None
import numpy as np

# %%
#Step 1 read in dataframe from assignment 2 and 3
df = pd.read_csv('data_traffic_road_segments.csv', index_col=False)
df = df[df['Road name'] == 'N1']
df = df.drop(df.columns[[0]], axis=1)
df = df.rename(columns = {'Start LRP':'LRPName'})
df.drop_duplicates(subset = 'LRPName', keep = 'last', inplace = True)

listLRP = df['LRPName'].unique()
trafficmodes = list(df)[12:-1]

for mode in trafficmodes:
    df[mode + ' Difference'] = df[mode] - df[mode].shift(1)
df.iloc[0, 28:43] = df.iloc[0, 12:27].tolist()
trafficdifference = list(df)[-15:-1]
absolutevalues = list()
for traffic in trafficdifference:
    absolutevalues.append(abs(df[traffic].iloc[0]) )
df.iloc[[0],-15:-1] = absolutevalues
for difference, mode in zip(trafficdifference,trafficmodes):
    df[difference] = np.where(df[difference] < 0, -(1 - (df[mode] / df[mode].shift(1))), df[difference])
    df[mode + ' Create'] = np.where(df[difference] > 0, df[difference], 0) 
    df[mode + ' Destroy'] = np.where(df[difference] < 0, abs(df[difference]), 0) 
CreateDestroy = list(df)[-28:]
df2 = pd.read_csv('data_clean_N1.csv')
df2 = df2.drop(df2.columns[[0,1]], axis=1)
for column in CreateDestroy:
    df2[column] = df2.LRPName.map(df.set_index('LRPName')[column].to_dict())
df2['ControlTraffic'] = np.where(df2['LRPName'].isin(listLRP), 'ControlTraffic', '')
columns = list(df2)[0:-1]
columns.insert(2, list(df2)[-1:][0])
df2 = df2.reindex(columns, axis = 1)
roundcols = list(df2)[10:]
scale = 10
for col in roundcols:
    df2[col] = np.where(df2['ControlTraffic'] == 'ControlTraffic', round((df2[col]/scale),5),np.NaN)
    for row in range(0,len(df2)):
        if df2[col].iloc[row] > 0 and df2[col].iloc[row] < 1:
            df2[col].iloc[row] = 1
df2['Add On Process'] = np.where(df2['Add On Process'] == 'BridgesDelay', 'BridgesDelay', '')
df2.Cat = df2.Cat.replace('0', '')
df2=df2.rename(columns = {'Add On Process':'BridgesDelay'})
df2['Index'] = df2.index + 1
for row in range(0, len(df2)):
    if df2.ControlTraffic.iloc[row] == 'ControlTraffic':
        df2.BridgesDelay.iloc[row] = 'DestroyTraffic'

# %%
df2[df2['ControlTraffic'] == 'ControlTraffic'].iloc[0:9]
# Out:
#     LRPName        Lat  ControlTraffic        Lon  Chainage Description  \
# 0      LRPS  23.706028  ControlTraffic  90.443333     0.000           0
# 18   LRP009  23.705028  ControlTraffic  90.519333     8.503           0
# 27   LRP012  23.691805  ControlTraffic  90.542611    11.497           0
# 32   LRP013  23.686527  ControlTraffic  90.550417    12.524           0
# 61   LRP022  23.625222  ControlTraffic  90.604972    21.629           0
# 89   LRP031  23.559972  ControlTraffic  90.654806    30.774           0
# 96   LRP033  23.548750  ControlTraffic  90.667833    32.607           0
# 128  LRP043  23.529416  ControlTraffic  90.751750    42.269           0
# 179  LRP067  23.497277  ControlTraffic  90.967472    65.726           0
#
#      Length Cat Next Node    BridgesDelay  Heavy Truck Create  \
# 0       0.0         LRPSa  DestroyTraffic             2.81027
# 18      0.0       LRP009a  DestroyTraffic             1.00000
# 27      0.0       LRP012a  DestroyTraffic             1.00000
# 32      0.0       LRP013a  DestroyTraffic             3.02040
# 61      0.0       LRP022a  DestroyTraffic             1.00000
# 89      0.0       LRP031a  DestroyTraffic             0.00000
# 96      0.0       LRP033b  DestroyTraffic             0.00000
# 128     0.0       LRP043a  DestroyTraffic             0.00000
# 179     0.0       LRP067a  DestroyTraffic             0.00000
#
#      Heavy Truck Destroy  Medium Truck Create  Medium Truck Destroy  \
# 0                    0.0             50.36136                   0.0
# 18                   0.0             56.31473                   0.0
# 27                   0.0              8.07016                   0.0
# 32                   0.0              6.09848                   0.0
# 61                   0.0              8.06776                   0.0
# 89                   0.0              0.00000                   0.0
# 96                   1.0              0.00000                   1.0
# 128                  1.0              0.00000                   1.0
# 179                  1.0              9.54167                   0.0
#
#      Small Truck Create  Small Truck Destroy  Large Bus Create  \
# 0              25.14631                  0.0          43.09076
# 18             51.00706                  0.0          27.11720
# 27              5.76108                  0.0           5.31131
# 32              0.00000                  1.0           0.00000
# 61              1.65924                  0.0           2.67543
# 89              0.00000                  0.0           0.00000
# 96              0.00000                  1.0           0.00000
# 128             0.00000                  1.0           0.00000
# 179             0.00000                  1.0           3.52500
#
#      Large Bus Destroy  Medium Bus Create  Medium Bus Destroy  \
# 0                  0.0           24.16658                 0.0
# 18                 0.0           34.93498                 0.0
# 27                 0.0            4.47110                 0.0
# 32                 1.0            0.00000                 1.0
# 61                 0.0            1.10303                 0.0
# 89                 0.0            0.00000                 0.0
# 96                 1.0            0.00000                 1.0
# 128                1.0            0.00000                 1.0
# 179                0.0            0.00000                 1.0
#
#      Micro Bus Create  Micro Bus Destroy  Utility Create  Utility Destroy  \
# 0            23.32436                0.0         5.71507              0.0
# 18           28.26304                0.0         1.03745              0.0
# 27            3.90264                0.0         1.00000              0.0
# 32            0.00000                1.0         2.09910              0.0
# 61            2.58938                0.0         1.00000              0.0
# 89            0.00000                0.0         0.00000              0.0
# 96            0.00000                1.0         0.00000              1.0
# 128           0.00000                1.0         0.00000              1.0
# 179           5.01667                0.0         1.00000              0.0
#
#      Car Create  Car Destroy  Auto Rickshaw Create  Auto Rickshaw Destroy  \
# 0      30.31135          0.0              50.24964                    0.0
# 18     11.56788          0.0              20.61766                    0.0
# 27      3.16821          0.0               5.36119                    0.0
# 32      2.97173          0.0               0.00000                    1.0
# 61      3.20583          0.0               1.94321                    0.0
# 89      0.00000          0.0               0.00000                    0.0
# 96      0.00000          1.0               0.00000                    1.0
# 128     0.00000          1.0               0.00000                    1.0
# 179     1.00000          0.0              19.30833                    0.0
#
#      Motor Cycle Create  Motor Cycle Destroy  Bi-Cycle Create  \
# 0              19.80938                  0.0          6.25650
# 18              6.30262                  0.0          2.01931
# 27              1.97540                  0.0          1.00000
# 32              0.00000                  1.0          0.00000
# 61              1.00000                  0.0          1.00000
# 89              0.00000                  0.0          0.00000
# 96              0.00000                  1.0          0.00000
# 128             0.00000                  1.0          0.00000
# 179             6.49167                  0.0          1.28333
#
#      Bi-Cycle Destroy  Cycle Rickshaw Create  Cycle Rickshaw Destroy  \
# 0                 0.0               22.41339                     0.0
# 18                0.0                7.23402                     0.0
# 27                0.0                2.24286                     0.0
# 32                1.0                0.00000                     1.0
# 61                0.0                1.00000                     0.0
# 89                0.0                0.00000                     0.0
# 96                1.0                0.00000                     1.0
# 128               1.0                0.00000                     1.0
# 179               0.0                1.00000                     0.0
#
#      Cart Create  Cart Destroy  Motorized Total Create  \
# 0            0.0           0.0               274.98508
# 18           0.0           0.0               238.06965
# 27           0.0           0.0                38.81314
# 32           0.0           0.0                 0.00000
# 61           0.0           0.0                22.66921
# 89           0.0           0.0                 0.00000
# 96           0.0           0.0                 0.00000
# 128          0.0           0.0                 0.00000
# 179          0.0           0.0                39.10000
#
#      Motorized Total Destroy  Index
# 0                        0.0      1
# 18                       0.0     19
# 27                       0.0     28
# 32                       1.0     33
# 61                       0.0     62
# 89                       0.0     90
# 96                       1.0     97
# 128                      1.0    129
# 179                      0.0    180

# %%
df2.head()
# Out:
#    LRPName        Lat  ControlTraffic        Lon  Chainage Description  \
# 0     LRPS  23.706028  ControlTraffic  90.443333     0.000           0
# 1    LRPSa  23.702917                  90.450417     0.814           0
# 2    LRPSb  23.702778                  90.450472     0.822           0
# 3   LRP001  23.702139                  90.451972     1.000           0
# 4  LRP001a  23.698739                  90.458861     1.800           .
#
#    Length Cat Next Node    BridgesDelay  Heavy Truck Create  \
# 0     0.0         LRPSa  DestroyTraffic             2.81027
# 1     0.0         LRPSb                                 NaN
# 2     0.0        LRP001                                 NaN
# 3     0.0       LRP001a                                 NaN
# 4    11.3   A    LRP002    BridgesDelay                 NaN
#
#    Heavy Truck Destroy  Medium Truck Create  Medium Truck Destroy  \
# 0                  0.0             50.36136                   0.0
# 1                  NaN                  NaN                   NaN
# 2                  NaN                  NaN                   NaN
# 3                  NaN                  NaN                   NaN
# 4                  NaN                  NaN                   NaN
#
#    Small Truck Create  Small Truck Destroy  Large Bus Create  \
# 0            25.14631                  0.0          43.09076
# 1                 NaN                  NaN               NaN
# 2                 NaN                  NaN               NaN
# 3                 NaN                  NaN               NaN
# 4                 NaN                  NaN               NaN
#
#    Large Bus Destroy  Medium Bus Create  Medium Bus Destroy  Micro Bus Create  \
# 0                0.0           24.16658                 0.0          23.32436
# 1                NaN                NaN                 NaN               NaN
# 2                NaN                NaN                 NaN               NaN
# 3                NaN                NaN                 NaN               NaN
# 4                NaN                NaN                 NaN               NaN
#
#    Micro Bus Destroy  Utility Create  Utility Destroy  Car Create  \
# 0                0.0         5.71507              0.0    30.31135
# 1                NaN             NaN              NaN         NaN
# 2                NaN             NaN              NaN         NaN
# 3                NaN             NaN              NaN         NaN
# 4                NaN             NaN              NaN         NaN
#
#    Car Destroy  Auto Rickshaw Create  Auto Rickshaw Destroy  \
# 0          0.0              50.24964                    0.0
# 1          NaN                   NaN                    NaN
# 2          NaN                   NaN                    NaN
# 3          NaN                   NaN                    NaN
# 4          NaN                   NaN                    NaN
#
#    Motor Cycle Create  Motor Cycle Destroy  Bi-Cycle Create  Bi-Cycle Destroy  \
# 0            19.80938                  0.0           6.2565               0.0
# 1                 NaN                  NaN              NaN               NaN
# 2                 NaN                  NaN              NaN               NaN
# 3                 NaN                  NaN              NaN               NaN
# 4                 NaN                  NaN              NaN               NaN
#
#    Cycle Rickshaw Create  Cycle Rickshaw Destroy  Cart Create  Cart Destroy  \
# 0               22.41339                     0.0          0.0           0.0
# 1                    NaN                     NaN          NaN           NaN
# 2                    NaN                     NaN          NaN           NaN
# 3                    NaN                     NaN          NaN           NaN
# 4                    NaN                     NaN          NaN           NaN
#
#    Motorized Total Create  Motorized Total Destroy  Index
# 0               274.98508                      0.0      1
# 1                     NaN                      NaN      2
# 2                     NaN                      NaN      3
# 3                     NaN                      NaN      4
# 4                     NaN                      NaN      5

# %%
#Step 2 - Run this line to link first part the script with the second part
df2.to_csv('AutoCreateSimioAssignment4.csv')
#df2.to_excel('AutoCreateSimioAssignment4.xlsx')

# %%
#Step 3 -OLD STEPS OF LOADING IN DATA --> For assignment 3
df_traffic = pd.read_csv('Traffic_segment_data.csv', encoding='utf-8',sep = ",")
df_BMSS_traffic_link = pd.read_csv('Bridge_data_with_link_to_traffic.csv',encoding='utf-8',sep = ",")
df_simio = pd.read_csv('AutoCreateSimioAssignment4.csv',encoding='utf-8',sep = ",")

#calculate segment score (we weigth vulnerability and criticality equally)
df_traffic["segment_score"] = ""
df_traffic["Road_cat"] = ""
df_traffic["segment_score"] = df_traffic["segment_vulnerability_normalized"] * df_traffic["Economic_Traffic_normalized"]

#Selecting the five most important segments on the N1 (on criticality and vulnerability and get list of LRP of bridges to sample from)
df_traffic_assignment_4 = df_traffic[df_traffic["Road_Name"]=="N1"]
df_traffic_assignment_4 = df_traffic_assignment_4.sort_values(by='segment_score', ascending=False)
df_traffic_assignment_4 = df_traffic_assignment_4[0:5]
df_traffic_assignment_4 = df_traffic_assignment_4[['Road_Name','Link_No','Link_Name','Start LRP','End LRP','Total_A','Total_B','Total_C','Total_D' ,'segment_score']]

Top_five_segments = df_traffic_assignment_4["Link_No"]
Top_five_segments = Top_five_segments.values.tolist()

#obtain LRP rows of bridges within the top 5 five segments to sample from in Simio
df_most_important_bridges = df_BMSS_traffic_link[df_BMSS_traffic_link["Road_segment_no"].isin(Top_five_segments)]
df_most_important_bridges = df_most_important_bridges[['name','LRPName','Road_segment_no','condition' ]]

#Obtain list of all LRP's of the bridges within those top 5 segments
important_bridges_list = df_most_important_bridges["LRPName"]
important_bridges_list = important_bridges_list.values.tolist()
#df_most_important_bridges.to_csv('data_five_most_important_segments', sep=',')

df_traffic_assignment_4
# Out:
#    Road_Name Link_No                                          Link_Name  \
# 35        N1   N1-36           Barabkunda Z1087-Fouzderhat Z1016 (Left)
# 6         N1    N1-7  Langalband - Mograpara Chowrasta (Left)Z1089 (...
# 68        N1   N1-69                             Whykong Z1133 - Teknaf
# 11        N1   N1-12              Daudkandi Z1062 - Pennai Z1053 (Left)
# 23        N1   N1-24  Miabazar Z1046 - Chauddagram(Int.with Z1045) (...
#
#    Start LRP End LRP  Total_A  Total_B  Total_C  Total_D  segment_score
# 35    LRP209  LRP225       18        6        2        2       0.096062
# 6     LRP013  LRP013        4        9        2        0       0.051326
# 68    LRP433  LRP467       74       25       38        3       0.045194
# 11    LRP033  LRP043        0        1        5        0       0.042074
# 23    LRP105  LRP105        7       12        0        0       0.041373

# %%
#Step 4 Iterate over the Simio dataframe to mark all important bridges for the add on process to break them down
df_simio["important_bridge"] = ""

for i in range(len(df_simio)):
    LRP = df_simio.iloc[i]['LRPName']
    if LRP in important_bridges_list:
        df_simio.important_bridge.loc[i,] = "True"
    else:
        df_simio.important_bridge.loc[i,] = "False"

# %%
#df_simio.info

# %%
#step 5 remove points only used in previous assignments
#df_simio["important_bridge"].value_counts()
df_simio["Next Node"].iloc[1553,] =""

# %%
#Step 6 Save resulting dataframe to use it as input for the Auto Creation of the model
df_simio.to_csv('AutoCreateSimioAssignment4.csv', sep=',')
