# %% [markdown]
# *Data-preparation script for visualisation*
#
# This script includes 15 steps:
# 1. Importing the packages
# 2. Read in all datafiles, the files that need to be in the same folder are
#     - BMMS_overview.csv
#     - _ roadnames _list.csv
#     - RMMS folder
# 3. Define values for truck capacity
# 4. three functions:
#     - htm_import
#     - process_traffic
#     - average_lanes
# 5. data per Road segments (Part 1)
# 6. Summary per road (Part 2)
# 7. Renaming / framing dataframes
# 8. Fix some of the missing data for segments
# 9. CHECK THE DATA CLEANING SCRIPT FOR MISSING SEGMENTS
# 10. RUN THIS LINE OF CODE FOR LINKING THE ROAD DATA WITH THE TRAFFIC (PER SEGMENT DATA)
# 11. CHECK HOW MUCH MISSING DATA IS THERE
# 12. Determine vulnerability of bridges based on their scenario likelihood
# 13. RUN THIS LINE OF CODE FOR CALCULATING THE VULNERABILITY OF EACH ROAD SEGMENT IN THE TRAFFIC DATA FILE
# 14. NORMALIZING Vulnerability & Criticality
# 15. Save the dataframe to CSV's to use them for the plotting scripts
#
# After the data-preparation there are three finalised documents, which are used for visualisation:
# - Traffic_segment_data.csv
# - Bridge_data_with_link_to_traffic.csv
# - summary_data_traffic_per_road.csv

# %%
#STEP 1: import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import html5lib
import numpy as np
import logging
warnings.filterwarnings('ignore')

# %%
#STEP 2 Read in all the data files
df_all_bmms = pd.read_csv('BMMS_overview.csv', encoding='utf-8',sep = ",")

#get list of all the roads 
roadnames = pd.read_csv('_roadnames_list.csv') # need to have roadnames list in same folder path 
roadnames_list = list(roadnames.columns.unique())

# %%
# Out:
#     road       km  Criticality               type  LRPName  \
# 0     N1    1.800          NaN        Box Culvert  LRP001a
# 1     N1    4.925          NaN        Box Culvert  LRP004b
# 2     N1    8.976          NaN   PC Girder Bridge  LRP008b
# 3     N1   10.880          NaN        Box Culvert  LRP010b
# 4     N1   10.897          NaN        Box Culvert  LRP010c
# 5     N1   11.296          NaN        Box Culvert  LRP011a
# 6     N1   12.239          NaN        Box Culvert  LRP012a
# 7     N1   12.253          NaN        Box Culvert  LRP012b
# 8     N1   12.660          NaN   PC Girder Bridge  LRP013a
# 9     N1   12.660          NaN   PC Girder Bridge  LRP013a
# 10    N1   12.660          NaN   PC Girder Bridge  LRP013a
# 11    N1   12.688          NaN   PC Girder Bridge  LRP013b
# 12    N1   13.574          NaN        Box Culvert  LRP014a
# 13    N1   17.222          NaN   PC Girder Bridge  LRP018b
# 14    N1   17.222          NaN   PC Girder Bridge  LRP018a
# 15    N1   18.093          NaN   PC Girder Bridge  LRP018c
# 16    N1   19.760          NaN        Box Culvert  LRP020a
# 17    N1   21.184          NaN   PC Girder Bridge  LRP021c
# 18    N1   21.184          NaN   PC Girder Bridge  LRP021d
# 19    N1   21.184          NaN   PC Girder Bridge  LRP021c
# 20    N1   22.596          NaN   PC Girder Bridge  LRP023a
# 21    N1   23.081          NaN   PC Girder Bridge  LRP023d
# 22    N1   23.081          NaN   PC Girder Bridge  LRP023c
# 23    N1   23.081          NaN   PC Girder Bridge  LRP023c
# 24    N1   24.393          NaN   PC Girder Bridge  LRP024a
# 25    N1   26.115          NaN        Box Culvert  LRP026a
# 26    N1   26.452          NaN        Box Culvert  LRP026b
# 27    N1   27.120          NaN        Box Culvert  LRP027a
# 28    N1   28.315          NaN   PC Girder Bridge  LRP028b
# 29    N1   28.315          NaN   PC Girder Bridge  LRP028a
# ..   ...      ...          ...                ...      ...
# 436   N1  450.759          NaN       Slab Culvert  LRP447a
# 437   N1  450.943          NaN        Box Culvert  LRP447b
# 438   N1  452.561          NaN  RCC Girder Bridge  LRP448c
# 439   N1  452.624          NaN  RCC Girder Bridge  LRP449a
# 440   N1  452.793          NaN       Slab Culvert  LRP449c
# 441   N1  454.219          NaN        Box Culvert  LRP450c
# 442   N1  454.330          NaN  RCC Girder Bridge  LRP450d
# 443   N1  454.330          NaN  RCC Girder Bridge  LRP450d
# 444   N1  454.498          NaN  RCC Girder Bridge  LRP450e
# 445   N1  454.769          NaN       Slab Culvert  LRP451b
# 446   N1  455.062          NaN  RCC Girder Bridge  LRP451c
# 447   N1  455.206          NaN       Slab Culvert  LRP451e
# 448   N1  455.366          NaN  RCC Girder Bridge  LRP451f
# 449   N1  455.447          NaN  RCC Girder Bridge  LRP451h
# 450   N1  455.447          NaN  RCC Girder Bridge  LRP451h
# 451   N1  455.496          NaN  RCC Girder Bridge  LRP451i
# 452   N1  455.496          NaN  RCC Girder Bridge  LRP451i
# 453   N1  455.688          NaN  RCC Girder Bridge  LRP452a
# 454   N1  455.765          NaN       Slab Culvert  LRP452c
# 455   N1  455.975          NaN       Slab Culvert  LRP452d
# 456   N1  456.064          NaN       Slab Culvert  LRP452e
# 457   N1  456.164          NaN  RCC Girder Bridge  LRP452f
# 458   N1  456.287          NaN  RCC Girder Bridge  LRP452h
# 459   N1  456.359          NaN  RCC Girder Bridge  LRP452i
# 460   N1  456.549          NaN  RCC Girder Bridge  LRP452j
# 461   N1  457.365          NaN  RCC Girder Bridge  LRP453a
# 462   N1  457.751          NaN  RCC Girder Bridge  LRP454a
# 463   N1  457.751          NaN  RCC Girder Bridge  LRP454a
# 464   N1  458.213          NaN  RCC Girder Bridge  LRP454b
# 465   N1  459.681          NaN        Box Culvert  LRP456a
#
#                               name  length condition  structureNr  \
# 0                                .   11.30         A       117861
# 1                                .    6.60         A       117862
# 2                Kanch pur Bridge.  394.23         A       119889
# 3                 NOYAPARA CULVERT    6.30         A       112531
# 4                   ADUPUR CULVERT    6.30         A       112532
# 5      NAYABARI KASPUR BOX CULVERT    8.30         A       101110
# 6            KHAS PARA BOX CULVERT    9.30         A       101117
# 7            DAWAN BAG BOX CULVERT    6.10         A       101119
# 8              Madanpur Bridge.(L)   27.50         A       119897
# 9                    MADAN PUR (R)   26.30         A       109841
# 10              MADANPUR BRIDGE(L)   26.30         A       109838
# 11              Madanpur Bridge(R)   27.50         A       119900
# 12             KAWTALA BOX CULVERT   11.90         A       109794
# 13            Darikandi Bridge (R)   20.45         A       119926
# 14            Darikandi Bridge (L)   20.50         A       119921
# 15              Sonakhal Bridge(L)   25.50         A       119933
# 16            KRIBORDI BOX CULVERT    6.00         A       109817
# 17             Marikhali Bridge(L)   86.92         A       119944
# 18             Marikhali Bridge(R)   89.75         A       119948
# 19                MARIKHALL BRIDGE   89.20         A       101103
# 20              ASHIR CHAR (Right)  224.80         A       109820
# 21        Asharirchar-2 Bridge.(R)  119.32         A       119964
# 22        Ashariachar-2 Bridge.(L)  119.48         A       119961
# 23                ASHARIR CHAR (L)  120.10         A       109796
# 24                   Meghna Bridge  924.85         A       119967
# 25               TATULTALA CULVERT    5.60         A       101132
# 26              BAILAKANDI CULVERT    5.50         A       101142
# 27             MALUAKANDI CULVEDRT    5.60         A       101150
# 28          Bhater char Bridge (L)  172.10         A       119976
# 29          Bhater char Bridge (R)  173.25         A       119973
# ..                             ...     ...       ...          ...
# 436          DONDO MIA BOX CULVERT    2.70         A       100899
# 437          DOMMO MIA BOX CULVERT    1.20         A       100894
# 438              Domodia Bridge(1)   13.50         A       120558
# 439             Domdomia Bridge(2)   13.50         A       120562
# 440                       DONDOMIA    2.70         A       100926
# 441           KARUNTON BOX CULVERT    1.20         A       100938
# 442      Karumtoli choto(1) Bridge    6.00         A       120569
# 443          KARUM TOLI SHOTHA (1)    6.00         A       100943
# 444            SHOLO BANDOR TAKNAF    6.00         A       100945
# 445       KARUMTOLI (3)BOX CULVERT    2.80         A       100954
# 446            Karumtoli(1) Bridge   33.70         A       120574
# 447         KARUM TOLI BOX CULVERT    1.30         A       100966
# 448            Karumtoli(2) Bridge   29.30         A       120575
# 449           Karumtoli (3) Bridge   10.60         A       120576
# 450    KARUM TOLI RCC GIDER BRIDGE   10.60         A       100968
# 451                Polashir Bridge   10.60         A       120578
# 452    KARAN TOLI RCC GIDER BRIDGE   10.60         A       100969
# 453    BAROY TOLI RCC GIDER BRIDGE   30.00         A       100970
# 454         BORY TOLI SLAB CULVERT    2.80         A       100913
# 455          BORYTOLI SLAB CULVERT    2.80         A       100912
# 456           BARITOLI BOX CULVERT    2.80         A       100910
# 457            Gilatoli (1) Bridge   17.50         A       120584
# 458               Baroytoli Bridge    8.30         A       120587
# 459           Baraytoli (3) Bridge    6.10         A       120588
# 460          Naiton Para(1) Bridge   23.00         A       120589
# 461         Naitom Para (2) Bridge   15.10         A       120592
# 462        Naitong Para (3) Bridge    9.00         A       120594
# 463  NAITANG PARA RCC GIDER BRIDGE    9.00         A       100897
# 464          Naitom Para(4) Bridge    9.00         A       120595
# 465   BUS STAND TEKNAF BOX CULVERT    1.50         A       100891
#
#                                               roadName      ...       width  \
# 0    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       19.50
# 1    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       35.40
# 2    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 3    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       12.20
# 4    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       12.20
# 5    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       21.45
# 6    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       21.00
# 7    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       20.60
# 8    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 9    Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        9.20
# 10   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        9.20
# 11   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 12   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       22.40
# 13   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 14   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 15   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 16   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       21.00
# 17   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 18   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 19   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        9.20
# 20   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        9.15
# 21   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 22   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 23   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        9.50
# 24   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 25   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.30
# 26   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       20.90
# 27   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       21.00
# 28   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 29   Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# ..                                                 ...      ...         ...
# 436  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.30
# 437  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.30
# 438  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 439  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 440  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.30
# 441  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        7.80
# 442  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 443  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        7.30
# 444  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        7.35
# 445  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.20
# 446  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 447  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       11.30
# 448  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 449  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 450  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        7.30
# 451  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 452  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        7.30
# 453  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        7.30
# 454  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.90
# 455  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.30
# 456  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.30
# 457  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 458  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 459  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 460  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 461  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 462  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 463  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...        7.40
# 464  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...         NaN
# 465  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      ...       10.30
#
#      constructionYear  spans        zone      circle     division  \
# 0              2005.0    2.0       Dhaka       Dhaka  Narayanganj
# 1              2006.0    1.0       Dhaka       Dhaka  Narayanganj
# 2                 NaN    NaN       Dhaka       Dhaka  Narayanganj
# 3              1992.0    2.0       Dhaka       Dhaka  Narayanganj
# 4              1984.0    2.0       Dhaka       Dhaka  Narayanganj
# 5              1986.0    2.0       Dhaka       Dhaka  Narayanganj
# 6              1986.0    2.0       Dhaka       Dhaka  Narayanganj
# 7              1987.0    2.0       Dhaka       Dhaka  Narayanganj
# 8                 NaN    NaN       Dhaka       Dhaka  Narayanganj
# 9              2003.0    1.0       Dhaka       Dhaka  Narayanganj
# 10             2003.0    1.0       Dhaka       Dhaka  Narayanganj
# 11                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 12             2003.0    2.0       Dhaka       Dhaka  Narayanganj
# 13                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 14                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 15                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 16             2001.0    1.0       Dhaka       Dhaka  Narayanganj
# 17                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 18                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 19             2000.0    3.0       Dhaka       Dhaka  Narayanganj
# 20             2004.0    9.0       Dhaka       Dhaka  Narayanganj
# 21                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 22                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 23             2000.0    4.0       Dhaka       Dhaka  Narayanganj
# 24                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 25             1989.0    1.0       Dhaka       Dhaka  Narayanganj
# 26             1989.0    1.0       Dhaka       Dhaka  Narayanganj
# 27             1989.0    1.0       Dhaka       Dhaka  Narayanganj
# 28                NaN    NaN       Dhaka       Dhaka  Narayanganj
# 29                NaN    NaN       Dhaka       Dhaka  Narayanganj
# ..                ...    ...         ...         ...          ...
# 436            1973.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 437            1973.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 438               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 439               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 440            1974.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 441            1987.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 442               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 443            1984.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 444            1986.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 445            1987.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 446               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 447            1978.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 448               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 449               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 450            1972.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 451               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 452            1993.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 453            1972.0    3.0  Chittagong  Chittagong  Cox's Bazar
# 454            1979.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 455            1981.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 456            1986.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 457               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 458               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 459               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 460               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 461               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 462               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 463            1982.0    1.0  Chittagong  Chittagong  Cox's Bazar
# 464               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 465            1991.0    1.0  Chittagong  Chittagong  Cox's Bazar
#
#         sub-division        lat        lon  EstimatedLoc
# 0      Narayanganj-1  23.698739  90.458861   interpolate
# 1      Narayanganj-1  23.694664  90.487775   interpolate
# 2      Narayanganj-1  23.705060  90.523214   interpolate
# 3          Vitikandi  23.694391  90.537574   interpolate
# 4          Vitikandi  23.694302  90.537707   interpolate
# 5          Vitikandi  23.692360  90.540918   interpolate
# 6          Vitikandi  23.688412  90.548559   interpolate
# 7          Vitikandi  23.688320  90.548650   interpolate
# 8          Vitikandi  23.685583  90.551208   interpolate
# 9          Vitikandi  23.685583  90.551208   interpolate
# 10         Vitikandi  23.685583  90.551208   interpolate
# 11         Vitikandi  23.685362  90.551359   interpolate
# 12         Vitikandi  23.677803  90.555819   interpolate
# 13         Vitikandi  23.653972  90.577410   interpolate
# 14         Vitikandi  23.653972  90.577410   interpolate
# 15         Vitikandi  23.649754  90.584549   interpolate
# 16         Vitikandi  23.637954  90.593667   interpolate
# 17         Vitikandi  23.628467  90.602302   interpolate
# 18         Vitikandi  23.628467  90.602302   interpolate
# 19         Vitikandi  23.628467  90.602302   interpolate
# 20         Vitikandi  23.617641  90.609551   interpolate
# 21         Vitikandi  23.613587  90.610903   interpolate
# 22         Vitikandi  23.613587  90.610903   interpolate
# 23         Vitikandi  23.613587  90.610903   interpolate
# 24         Vitikandi  23.602760  90.615532   interpolate
# 25         Vitikandi  23.592982  90.627970   interpolate
# 26         Vitikandi  23.590809  90.630237   interpolate
# 27         Vitikandi  23.586318  90.634509   interpolate
# 28         Vitikandi  23.577980  90.641919   interpolate
# 29         Vitikandi  23.577980  90.641919   interpolate
# ..               ...        ...        ...           ...
# 436  Cox's Bazar - 2  20.947095  92.259788   interpolate
# 437  Cox's Bazar - 2  20.945851  92.260333   interpolate
# 438  Cox's Bazar - 2  20.932426  92.263613   interpolate
# 439  Cox's Bazar - 2  20.931876  92.263713   interpolate
# 440  Cox's Bazar - 2  20.930400  92.263979   interpolate
# 441  Cox's Bazar - 2  20.918888  92.268708   interpolate
# 442  Cox's Bazar - 2  20.917996  92.269101   interpolate
# 443  Cox's Bazar - 2  20.917996  92.269101   interpolate
# 444  Cox's Bazar - 2  20.916707  92.269857   interpolate
# 445  Cox's Bazar - 2  20.914635  92.271207   interpolate
# 446  Cox's Bazar - 2  20.912675  92.272721   interpolate
# 447  Cox's Bazar - 2  20.911624  92.273342   interpolate
# 448  Cox's Bazar - 2  20.910429  92.274140   interpolate
# 449  Cox's Bazar - 2  20.909823  92.274543   interpolate
# 450  Cox's Bazar - 2  20.909823  92.274543   interpolate
# 451  Cox's Bazar - 2  20.909457  92.274787   interpolate
# 452  Cox's Bazar - 2  20.909457  92.274787   interpolate
# 453  Cox's Bazar - 2  20.908032  92.275691   interpolate
# 454  Cox's Bazar - 2  20.907448  92.276059   interpolate
# 455  Cox's Bazar - 2  20.905977  92.277086   interpolate
# 456  Cox's Bazar - 2  20.905305  92.277574   interpolate
# 457  Cox's Bazar - 2  20.904572  92.278077   interpolate
# 458  Cox's Bazar - 2  20.903691  92.278693   interpolate
# 459  Cox's Bazar - 2  20.903203  92.279045   interpolate
# 460  Cox's Bazar - 2  20.901885  92.279874   interpolate
# 461  Cox's Bazar - 2  20.897099  92.285061   interpolate
# 462  Cox's Bazar - 2  20.895090  92.287952   interpolate
# 463  Cox's Bazar - 2  20.895090  92.287952   interpolate
# 464  Cox's Bazar - 2  20.892271  92.290984   interpolate
# 465  Cox's Bazar - 2  20.884567  92.298716   interpolate
#
# [466 rows x 21 columns]

# %%
#STEP 3 Define the relative values of the trucks according to economic value equation, SEE chapter 1.2.2 for explanation.
Heavy_value = 30.0
Medium_value = 25.0
Small_value = 16.0

# %%
#STEP 4.1 - Load in functions
#function that takes the roadname as an argument and returns a panda dataframe with the traffic data for that road
def htm_import(roadname):
        
        #make a temporary dataframe that will be returned by the function
        df_current_road = pd.DataFrame()
        
        #get filename and open the .htm file
        filename = "RMMS/{}.traffic.htm".format(roadname)
        f =  open(filename, "rb")
        
        #find all the dataframes that contain the string of the roadname
        list_road = pd.read_html(f, skiprows = {0,0,5},header  = 1, match = roadname) #the third data frame has 5 skip rows
        df_current_road = list_road[2] #third table in the file is the data frame with the traffic data
        f.close()

        #subset to remove all columns after the 25th column. 
        #The 26th column is a repeat of total AADT data in 25th column and after that there are a number of empty columns 
        #as a result of parsing from .htm that should also be removed
        column_remove =list(df_current_road.columns.values)[25:]
        df_current_road = df_current_road.drop(labels=column_remove, axis = 1)

        #rename the columns
        df_current_road.columns = ["Link no","Link Name","Start LRP","Start Offset","Start Chainage","End LRP","End Offset","End Chainage","Link Length", "Heavy Truck","Medium Truck","Small Truck","Large Bus","Medium Bus","Micro Bus","Utility","Car","Auto Rickshaw","Motor Cycle","Bi-Cycle","Cycle Rickshaw","Cart","Motorized Total","Non Motorized Total","Total Traffic"]       

        #include the roadname in the dataframe
        df_current_road['Road name'] = roadname
        return(df_current_road)

# %%
#STEP 4.2 - Load in functions
#involves calculating the economic value of the traffic on each 'link', and processing duplicates for L and R on a link.
#the average value of L and R traffc is used, and then the R values are removed
#also removes links for which there is no data at all, and returns a list of the links that have been removed
def process_traffic(df):

    end_index = len(df)
    drop_indices = [] #list containing indices of duplictates to be removed
    for i in range(end_index):
        
        #check for missing data in the link
        if df.iloc[i]['Heavy Truck'] == 'NS' :
            #all the rows with NS data (i.e missing data) have NS values in this column
            #remove the 'bad data row' - but maybe change to NA instead?
            drop_indices.append(i)
            #report deletion to log
            logging.warning('%s link deleted due to no data',df.iloc[i]['Link no'] )
        elif  i != (end_index-1):
            if df.iloc[i+1]['Heavy Truck'] != 'NS':
     
                #no missing values so continue as normal...
                #EXTEND THIS CONDITION TO MAKE IT MORE ACCURATE (MAYBE NOT NECESSARY): same chainage/name etc also
                if 'L' in df.iloc[i]['Link no'] and 'R' in df.iloc[i+1]['Link no']:

                    if not (df.iloc[i+1]['Heavy Truck'] == 'NS'): #cannot average with next row's value if the next row is corrupt data


                                #use average of all the traffic data from L and R 
                                df.iloc[i, df.columns.get_loc('Heavy Truck')] = (float(df.iloc[i]['Heavy Truck'])+float(df.iloc[i+1]['Heavy Truck']))/2
                                df.iloc[i, df.columns.get_loc('Medium Truck')] = (float(df.iloc[i]['Medium Truck'])+float(df.iloc[i+1]['Medium Truck']))/2
                                df.iloc[i, df.columns.get_loc('Small Truck')] = (float(df.iloc[i]['Small Truck'])+float(df.iloc[i+1]['Small Truck']))/2

                                df.iloc[i, df.columns.get_loc('Large Bus')] = (float(df.iloc[i]['Large Bus'])+float(df.iloc[i+1]['Large Bus']))/2
                                df.iloc[i, df.columns.get_loc('Medium Bus')] = (float(df.iloc[i]['Medium Bus'])+float(df.iloc[i+1]['Medium Bus']))/2
                                df.iloc[i, df.columns.get_loc('Micro Bus')] = (float(df.iloc[i]['Micro Bus'])+float(df.iloc[i+1]['Micro Bus']))/2

                                df.iloc[i, df.columns.get_loc('Utility')] = (float(df.iloc[i]['Utility'])+float(df.iloc[i+1]['Utility']))/2

                                df.iloc[i, df.columns.get_loc('Car')] = (float(df.iloc[i]['Car'])+float(df.iloc[i+1]['Car']))/2
                                df.iloc[i, df.columns.get_loc('Auto Rickshaw')] = (float(df.iloc[i]['Auto Rickshaw'])+float(df.iloc[i+1]['Auto Rickshaw']))/2
                                df.iloc[i, df.columns.get_loc('Motor Cycle')] = (float(df.iloc[i]['Motor Cycle'])+float(df.iloc[i+1]['Motor Cycle']))/2
                                df.iloc[i, df.columns.get_loc('Bi-Cycle')] = (float(df.iloc[i]['Bi-Cycle'])+float(df.iloc[i+1]['Bi-Cycle']))/2        
                                df.iloc[i, df.columns.get_loc('Cycle Rickshaw')] = (float(df.iloc[i]['Cycle Rickshaw'])+float(df.iloc[i+1]['Cycle Rickshaw']))/2
                                df.iloc[i, df.columns.get_loc('Cart')] = (float(df.iloc[i]['Cart'])+float(df.iloc[i+1]['Cart']))/2

                                df.iloc[i, df.columns.get_loc('Motorized Total')] = (float(df.iloc[i]['Motorized Total'])+float(df.iloc[i+1]['Motorized Total']))/2        
                                df.iloc[i, df.columns.get_loc('Non Motorized Total')] = (float(df.iloc[i]['Non Motorized Total'])+float(df.iloc[i+1]['Non Motorized Total']))/2        
                                df.iloc[i, df.columns.get_loc('Total Traffic')] = (float(df.iloc[i]['Total Traffic'])+float(df.iloc[i+1]['Total Traffic']))/2        

                                #remove the duplicate
                                drop_indices.append(i+1)
                                logging.warning('%s link deleted due to duplicate',df.iloc[i]['Link no'] )

                                #rename the Link no (e.g. N1-1R is removed and N1-1L is renamed N1-1)
                                df.iloc[i, df.columns.get_loc('Link no')] = df.iloc[i]['Link no'].replace('L','')

    df.drop(labels = drop_indices, inplace = True)
    
    for i in range(len(df)):      
        #calculate the "economic value of traffic" according to formula
        df.iloc[i, df.columns.get_loc("Economic Traffic")] = float(df.iloc[i]['Heavy Truck'])*Heavy_value+float(df.iloc[i]['Medium Truck'])*Medium_value + float(df.iloc[i]['Small Truck'])*Small_value


    return(df)
    #question: do we also want to rename any single R or L link numbers? Or is this okay? I think it is more informative this way...?

# %%
#STEP 4.3 - Load in functions
#function to return the 'average number of lanes over a segment of road'...weighted by the length for which the road
#has that many lanes
#input arguments: start chainage of road segment (km), end chainage of road segment (km), segment length (km), data frame of lane/width dtaa for that road
#output arguments: 'average number of lanes over that segment of road'
def average_lanes (a,b,segment_length, df):
    weighted_lanes = 0.0 
    
    for i in range(len(df)):
        start = df.iloc[i]['startChainage']
        end = df.iloc[i]['endChainage']
        lanes = df.iloc[i]['nrLanes']
        if not((a > end) or (b < start)):
            
            if a <= start and b >= end:
                #entire part of the lane segment is on the road segment
                weighted_lanes += (end-start)*lanes

            elif a >= start and b>= end:
                #end part of the lane segment is on the road segment
                weighted_lanes += (end-a)*lanes

            elif (a < start) and (b < end):
                #beginning part of the lane segment is on the road segment
                weighted_lanes += (b-start)*lanes

            elif (a >= start) and (b<= end):
                #entire road segment is within a lane segment
                weighted_lanes += (b-a)*lanes

        #else no part of that lane segment is on the road segment
    if weighted_lanes == 0.0:
        return (-1) #no lane data found that matched, -1 is the indicator of this error
    
    
        #finally, return the number of lanes, averaged by length of the total lanes
    return (weighted_lanes/segment_length)

# %%
#STEP 5 - Get traffic data for all road segments
#MAIN BLOCK OF CODE, PART 1: Road Segments

#create the output data frame with corresponding columns for output
df_traffic_allroads = pd.DataFrame(columns =["Road name","Link no","Link Name","Start LRP","Start Offset","Start Chainage","End LRP","End Offset","End Chainage","Link Length", "Economic Traffic","No Lanes","Heavy Truck","Medium Truck","Small Truck","Large Bus","Medium Bus","Micro Bus","Utility","Car","Auto Rickshaw","Motor Cycle","Bi-Cycle","Cycle Rickshaw","Cart","Motorized Total","Non Motorized Total","Total Traffic"])

#get list of all the roads 
roadnames = pd.read_csv('_roadnames_list.csv') # need to have roadnames list in same folder path 
roadnames_list = list(roadnames.columns.unique())

#iterate through each road and append it to the main dataframe using defined function htm_import
for roadname in roadnames_list:
    df_traffic_allroads = df_traffic_allroads.append(htm_import(roadname), ignore_index = True, sort = False)


#call function to process the data from htm: ie. remove duplicates, and find the criticality of each segment
df_traffic_allroads = process_traffic(df_traffic_allroads)

#next section of code (for loop) calls the function to calculate the average number of lanes in each road segment
#iterate through each road segment on the database
road_name_previous = 'Na' #initialise for first comparison
for i in range(len(df_traffic_allroads)):
    
    road_name_current = df_traffic_allroads.iloc[i]['Road name']
    #check if segmnet of road is on a different road
    if (road_name_current != road_name_previous):
        #open new file
        filename = "RMMS/{}.widths.processed.txt".format(road_name_current)
        f =  open(filename, "rb")
        df_lanes = pd.read_csv(f, sep='\t', lineterminator='\n')
        df_lanes.columns = ['roadNo', 'roadId', 'startChainage', 'endChainage', 'width','nrLanes']

    a = df_traffic_allroads.iloc[i]['Start Chainage']
    b = df_traffic_allroads.iloc[i]['End Chainage']
    length = df_traffic_allroads.iloc[i]['Link Length']
    
    #calculate average value of lanes using function and update the data frame
    df_traffic_allroads.iloc[i, df_traffic_allroads.columns.get_loc('No Lanes')] = average_lanes(a,b,length,df_lanes)
    
    #pass into memory for next comparison
    road_name_previous = road_name_current

#call function that converts all traffic modes into traffic density for that mode
df = df_traffic_allroads
for i in range(len(df)):
    lanes = df.iloc[i]['No Lanes']

    if  lanes == -1 :
    #mark as NA using numpy.nan
        df.iloc[i, df.columns.get_loc('Heavy Truck')] = np.nan
        df.iloc[i, df.columns.get_loc('Medium Truck')] = np.nan
        df.iloc[i, df.columns.get_loc('Small Truck')] = np.nan
                    
        df.iloc[i, df.columns.get_loc('Large Bus')] = np.nan
        df.iloc[i, df.columns.get_loc('Medium Bus')] = np.nan
        df.iloc[i, df.columns.get_loc('Micro Bus')] = np.nan
                    
        df.iloc[i, df.columns.get_loc('Utility')] = np.nan
                    
        df.iloc[i, df.columns.get_loc('Car')] = np.nan
        df.iloc[i, df.columns.get_loc('Auto Rickshaw')] =np.nan
        df.iloc[i, df.columns.get_loc('Motor Cycle')] = np.nan
        df.iloc[i, df.columns.get_loc('Bi-Cycle')] = np.nan    
        df.iloc[i, df.columns.get_loc('Cycle Rickshaw')] = np.nan
        df.iloc[i, df.columns.get_loc('Cart')] = np.nan
                    
        df.iloc[i, df.columns.get_loc('Motorized Total')] = np.nan     
        df.iloc[i, df.columns.get_loc('Non Motorized Total')] = np.nan      
        df.iloc[i, df.columns.get_loc('Total Traffic')] = np.nan
                           
    else:

        #convert from traffic to traffic density
        df.iloc[i, df.columns.get_loc('Heavy Truck')] = float((df.iloc[i]['Heavy Truck']))/lanes
        df.iloc[i, df.columns.get_loc('Medium Truck')] = float((df.iloc[i]['Medium Truck']))/lanes
        df.iloc[i, df.columns.get_loc('Small Truck')] = float((df.iloc[i]['Small Truck']))/lanes
                    
        df.iloc[i, df.columns.get_loc('Large Bus')] = float((df.iloc[i]['Large Bus']))/lanes
        df.iloc[i, df.columns.get_loc('Medium Bus')] = float((df.iloc[i]['Medium Bus']))/lanes
        df.iloc[i, df.columns.get_loc('Micro Bus')] = float((df.iloc[i]['Micro Bus']))/lanes
                    
        df.iloc[i, df.columns.get_loc('Utility')] = float((df.iloc[i]['Utility']))/lanes
                    
        df.iloc[i, df.columns.get_loc('Car')] = float((df.iloc[i]['Car']))/lanes
        df.iloc[i, df.columns.get_loc('Auto Rickshaw')] = float((df.iloc[i]['Auto Rickshaw']))/lanes
        df.iloc[i, df.columns.get_loc('Motor Cycle')] = float((df.iloc[i]['Motor Cycle']))/lanes
        df.iloc[i, df.columns.get_loc('Bi-Cycle')] = float((df.iloc[i]['Bi-Cycle']))/lanes       
        df.iloc[i, df.columns.get_loc('Cycle Rickshaw')] = float((df.iloc[i]['Cycle Rickshaw']))/lanes
        df.iloc[i, df.columns.get_loc('Cart')] = float((df.iloc[i]['Cart']))/lanes
                    
        df.iloc[i, df.columns.get_loc('Motorized Total')] = float((df.iloc[i]['Motorized Total']))/lanes     
        df.iloc[i, df.columns.get_loc('Non Motorized Total')] = float((df.iloc[i]['Non Motorized Total']))/lanes      
        df.iloc[i, df.columns.get_loc('Total Traffic')] = float((df.iloc[i]['Total Traffic']))/lanes
# Out:
# WARNING:root:N1-1L link deleted due to duplicate
# WARNING:root:N1-3L link deleted due to duplicate
# WARNING:root:N1-4L link deleted due to duplicate
# WARNING:root:N1-5L link deleted due to duplicate
# WARNING:root:N1-6L link deleted due to duplicate
# WARNING:root:N1-7L link deleted due to duplicate
# WARNING:root:N1-8L link deleted due to duplicate
# WARNING:root:N1-9L link deleted due to duplicate
# WARNING:root:N1-10L link deleted due to duplicate
# WARNING:root:N1-11L link deleted due to duplicate
# WARNING:root:N1-12L link deleted due to duplicate
# WARNING:root:N1-13L link deleted due to duplicate
# WARNING:root:N1-14L link deleted due to duplicate
# WARNING:root:N1-15L link deleted due to duplicate
# WARNING:root:N1-16L link deleted due to duplicate
# WARNING:root:N1-17L link deleted due to duplicate
# WARNING:root:N1-18L link deleted due to duplicate
# WARNING:root:N1-19L link deleted due to duplicate
# WARNING:root:N1-20L link deleted due to duplicate
# WARNING:root:N1-21L link deleted due to duplicate
# WARNING:root:N1-22L link deleted due to duplicate
# WARNING:root:N1-23L link deleted due to duplicate
# WARNING:root:N1-24L link deleted due to duplicate
# WARNING:root:N1-25L link deleted due to duplicate
# WARNING:root:N1-26L link deleted due to duplicate
# WARNING:root:N1-27L link deleted due to duplicate
# WARNING:root:N1-28L link deleted due to duplicate
# WARNING:root:N1-29L link deleted due to duplicate
# WARNING:root:N1-30L link deleted due to duplicate
# WARNING:root:N1-31L link deleted due to duplicate
# WARNING:root:N1-32L link deleted due to duplicate
# WARNING:root:N1-33L link deleted due to duplicate
# WARNING:root:N1-34L link deleted due to duplicate
# WARNING:root:N1-35L link deleted due to duplicate
# WARNING:root:N1-36L link deleted due to duplicate
# WARNING:root:N123-1 link deleted due to no data
# WARNING:root:N123-2 link deleted due to no data
# WARNING:root:N124-1 link deleted due to no data
# WARNING:root:N125-1 link deleted due to no data
# WARNING:root:N126-1 link deleted due to no data
# WARNING:root:N127-1 link deleted due to no data
# WARNING:root:N128-1 link deleted due to no data
# WARNING:root:N129-1 link deleted due to no data
# WARNING:root:N212-1L link deleted due to duplicate
# WARNING:root:N3-1L link deleted due to duplicate
# WARNING:root:N3-3L link deleted due to duplicate
# WARNING:root:N3-4L link deleted due to duplicate
# WARNING:root:N3-5L link deleted due to duplicate
# WARNING:root:N3-6L link deleted due to duplicate
# WARNING:root:N3-7L link deleted due to duplicate
# WARNING:root:N3-8L link deleted due to duplicate
# WARNING:root:N3-9L link deleted due to duplicate
# WARNING:root:N3-10L link deleted due to duplicate
# WARNING:root:N3-11L link deleted due to duplicate
# WARNING:root:N3-12L link deleted due to duplicate
# WARNING:root:N3-13L link deleted due to duplicate
# WARNING:root:N3-14L link deleted due to duplicate
# WARNING:root:N3-15L link deleted due to duplicate
# WARNING:root:N3-16L link deleted due to duplicate
# WARNING:root:N3-17L link deleted due to duplicate
# WARNING:root:N3-18L link deleted due to duplicate
# WARNING:root:N406-2 link deleted due to no data
# WARNING:root:N5-1L link deleted due to duplicate
# WARNING:root:N5-2L link deleted due to duplicate
# WARNING:root:N5-3L link deleted due to duplicate
# WARNING:root:N5-37 link deleted due to no data
# WARNING:root:N5-50L link deleted due to duplicate
# WARNING:root:N514-1L link deleted due to duplicate
# WARNING:root:N517-4L link deleted due to duplicate
# WARNING:root:N540-1L link deleted due to duplicate
# WARNING:root:N709-3L link deleted due to duplicate
# WARNING:root:N801-1 link deleted due to no data
# WARNING:root:N803-1L link deleted due to duplicate
# WARNING:root:N809-1L link deleted due to duplicate
# WARNING:root:R682-1 link deleted due to no data
# WARNING:root:R743-1 link deleted due to no data
# WARNING:root:R745-12L link deleted due to duplicate
# WARNING:root:Z1002-2 link deleted due to no data
# WARNING:root:Z1012-1 link deleted due to no data
# WARNING:root:Z1012-2 link deleted due to no data
# WARNING:root:Z1016-1 link deleted due to no data
# WARNING:root:Z1019-2 link deleted due to no data
# WARNING:root:Z1021-1 link deleted due to no data
# WARNING:root:Z1029-1 link deleted due to no data
# WARNING:root:Z1030-2 link deleted due to no data
# WARNING:root:Z1031-1 link deleted due to no data
# WARNING:root:Z1031-2 link deleted due to no data
# WARNING:root:Z1031-4 link deleted due to no data
# WARNING:root:Z1031-5 link deleted due to no data
# WARNING:root:Z1031-6 link deleted due to no data
# WARNING:root:Z1031-7 link deleted due to no data
# WARNING:root:Z1031-8 link deleted due to no data
# WARNING:root:Z1031-9 link deleted due to no data
# WARNING:root:Z1031-10 link deleted due to no data
# WARNING:root:Z1033-2 link deleted due to no data
# WARNING:root:Z1034-4 link deleted due to no data
# WARNING:root:Z1036-2 link deleted due to no data
# WARNING:root:Z1038-1 link deleted due to no data
# WARNING:root:Z1040-2 link deleted due to no data
# WARNING:root:Z1041-1 link deleted due to no data
# WARNING:root:Z1042-2 link deleted due to no data
# WARNING:root:Z1043-1 link deleted due to no data
# WARNING:root:Z1044-2 link deleted due to no data
# WARNING:root:Z1046-2 link deleted due to no data
# WARNING:root:Z1047-1 link deleted due to no data
# WARNING:root:Z1048-2 link deleted due to no data
# WARNING:root:Z1052-2 link deleted due to no data
# WARNING:root:Z1059-2 link deleted due to no data
# WARNING:root:Z1062-2 link deleted due to no data
# WARNING:root:Z1066-1 link deleted due to no data
# WARNING:root:Z1070-1 link deleted due to no data
# WARNING:root:Z1086-1 link deleted due to no data
# WARNING:root:Z1089-1 link deleted due to no data
# WARNING:root:Z1121-1 link deleted due to no data
# WARNING:root:Z1121-2 link deleted due to no data
# WARNING:root:Z1122-1 link deleted due to no data
# WARNING:root:Z1123-1 link deleted due to no data
# WARNING:root:Z1124-1 link deleted due to no data
# WARNING:root:Z1125-2 link deleted due to no data
# WARNING:root:Z1126-2 link deleted due to no data
# WARNING:root:Z1201-2 link deleted due to no data
# WARNING:root:Z1202-2 link deleted due to no data
# WARNING:root:Z1205-1 link deleted due to no data
# WARNING:root:Z1219-1 link deleted due to no data
# WARNING:root:Z1219-2 link deleted due to no data
# WARNING:root:Z1220-1 link deleted due to no data
# WARNING:root:Z1401-2 link deleted due to no data
# WARNING:root:Z1405-1 link deleted due to no data
# WARNING:root:Z1405-4 link deleted due to no data
# WARNING:root:Z1407-2 link deleted due to no data
# WARNING:root:Z1412-1 link deleted due to no data
# WARNING:root:Z1416-2 link deleted due to no data
# WARNING:root:Z1417-1 link deleted due to no data
# WARNING:root:Z1417-2 link deleted due to no data
# WARNING:root:Z1421-1 link deleted due to no data
# WARNING:root:Z1421-2 link deleted due to no data
# WARNING:root:Z1421-4 link deleted due to no data
# WARNING:root:Z1422-2 link deleted due to no data
# WARNING:root:Z1429-2 link deleted due to no data
# WARNING:root:Z1437-1 link deleted due to no data
# WARNING:root:Z1438-1 link deleted due to no data
# WARNING:root:Z1439-1 link deleted due to no data
# WARNING:root:Z1482-2 link deleted due to no data
# WARNING:root:Z1603-2 link deleted due to no data
# WARNING:root:Z1617-1 link deleted due to no data
# WARNING:root:Z1629-2 link deleted due to no data
# WARNING:root:Z1802-2 link deleted due to no data
# WARNING:root:Z1806-1 link deleted due to no data
# WARNING:root:Z1811-2 link deleted due to no data
# WARNING:root:Z1811-4 link deleted due to no data
# WARNING:root:Z2002-2 link deleted due to no data
# WARNING:root:Z2003-2 link deleted due to no data
# WARNING:root:Z2010-1 link deleted due to no data
# WARNING:root:Z2031-1 link deleted due to no data
# WARNING:root:Z2037-2 link deleted due to no data
# WARNING:root:Z2039-2 link deleted due to no data
# WARNING:root:Z2044-2 link deleted due to no data
# WARNING:root:Z2045-2 link deleted due to no data
# WARNING:root:Z2047-2 link deleted due to no data
# WARNING:root:Z2055-1 link deleted due to no data
# WARNING:root:Z2403-2 link deleted due to no data
# WARNING:root:Z2801-1 link deleted due to no data
# WARNING:root:Z2801-2 link deleted due to no data
# WARNING:root:Z2802-2 link deleted due to no data
# WARNING:root:Z2804-2 link deleted due to no data
# WARNING:root:Z2824-1 link deleted due to no data
# WARNING:root:Z3004-1 link deleted due to no data
# WARNING:root:Z3006-1 link deleted due to no data
# WARNING:root:Z3008-2 link deleted due to no data
# WARNING:root:Z3025-2 link deleted due to no data
# WARNING:root:Z3033-1 link deleted due to no data
# WARNING:root:Z3033-4 link deleted due to no data
# WARNING:root:Z3035-1 link deleted due to no data
# WARNING:root:Z3036-1 link deleted due to no data
# WARNING:root:Z3038-1 link deleted due to no data
# WARNING:root:Z3042-1 link deleted due to no data
# WARNING:root:Z3604-1 link deleted due to no data
# WARNING:root:Z3605-1 link deleted due to no data
# WARNING:root:Z3617-1 link deleted due to no data
# WARNING:root:Z3623-1 link deleted due to no data
# WARNING:root:Z3701-1 link deleted due to no data
# WARNING:root:Z3707-2 link deleted due to no data
# WARNING:root:Z3708-1 link deleted due to no data
# WARNING:root:Z3711-2 link deleted due to no data
# WARNING:root:Z4018-1 link deleted due to no data
# WARNING:root:Z4019-1 link deleted due to no data
# WARNING:root:Z4020-1 link deleted due to no data
# WARNING:root:Z4021-2 link deleted due to no data
# WARNING:root:Z4023-2 link deleted due to no data
# WARNING:root:Z4101-2 link deleted due to no data
# WARNING:root:Z4605-2 link deleted due to no data
# WARNING:root:Z4606-1 link deleted due to no data
# WARNING:root:Z4606-4 link deleted due to no data
# WARNING:root:Z4606-5 link deleted due to no data
# WARNING:root:Z4607-1 link deleted due to no data
# WARNING:root:Z4609-1 link deleted due to no data
# WARNING:root:Z4801-2 link deleted due to no data
# WARNING:root:Z5002-4 link deleted due to no data
# WARNING:root:Z5003-2 link deleted due to no data
# WARNING:root:Z5006-2 link deleted due to no data
# WARNING:root:Z5008-2 link deleted due to no data
# WARNING:root:Z5010-1 link deleted due to no data
# WARNING:root:Z5010-4 link deleted due to no data
# WARNING:root:Z5012-1 link deleted due to no data
# WARNING:root:Z5025-1 link deleted due to no data
# WARNING:root:Z5032-2 link deleted due to no data
# WARNING:root:Z5040-2 link deleted due to no data
# WARNING:root:Z5043-1 link deleted due to no data
# WARNING:root:Z5044-1 link deleted due to no data
# WARNING:root:Z5046-2 link deleted due to no data
# WARNING:root:Z5063-1 link deleted due to no data
# WARNING:root:Z5064-1 link deleted due to no data
# WARNING:root:Z5070-1 link deleted due to no data
# WARNING:root:Z5072-2 link deleted due to no data
# WARNING:root:Z5072-4 link deleted due to no data
# WARNING:root:Z5072-5 link deleted due to no data
# WARNING:root:Z5080-1 link deleted due to no data
# WARNING:root:Z5202-4 link deleted due to no data
# WARNING:root:Z5207-2 link deleted due to no data
# WARNING:root:Z5209-2 link deleted due to no data
# WARNING:root:Z5210-2 link deleted due to no data
# WARNING:root:Z5211-2 link deleted due to no data
# WARNING:root:Z5301-1 link deleted due to no data
# WARNING:root:Z5402-2 link deleted due to no data
# WARNING:root:Z5403-1 link deleted due to no data
# WARNING:root:Z5406-2 link deleted due to no data
# WARNING:root:Z5409-1 link deleted due to no data
# WARNING:root:Z5409-2 link deleted due to no data
# WARNING:root:Z5409-4 link deleted due to no data
# WARNING:root:Z5456-2 link deleted due to no data
# WARNING:root:Z5463-1 link deleted due to no data
# WARNING:root:Z5471-2 link deleted due to no data
# WARNING:root:Z5503-1 link deleted due to no data
# WARNING:root:Z5503-2 link deleted due to no data
# WARNING:root:Z5503-4 link deleted due to no data
# WARNING:root:Z5508-1 link deleted due to no data
# WARNING:root:Z5508-4 link deleted due to no data
# WARNING:root:Z5509-2 link deleted due to no data
# WARNING:root:Z5554-1 link deleted due to no data
# WARNING:root:Z5613-1 link deleted due to no data
# WARNING:root:Z5616-2 link deleted due to no data
# WARNING:root:Z5617-1 link deleted due to no data
# WARNING:root:Z5701-2 link deleted due to no data
# WARNING:root:Z5703-2 link deleted due to no data
# WARNING:root:Z5706-1 link deleted due to no data
# WARNING:root:Z5707-1 link deleted due to no data
# WARNING:root:Z5709-2 link deleted due to no data
# WARNING:root:Z5855-2 link deleted due to no data
# WARNING:root:Z5857-2 link deleted due to no data
# WARNING:root:Z5858-1 link deleted due to no data
# WARNING:root:Z5903-1 link deleted due to no data
# WARNING:root:Z5904-2 link deleted due to no data
# WARNING:root:Z6004-2 link deleted due to no data
# WARNING:root:Z6006-2 link deleted due to no data
# WARNING:root:Z6014-2 link deleted due to no data
# WARNING:root:Z6015-4 link deleted due to no data
# WARNING:root:Z6019-2 link deleted due to no data
# WARNING:root:Z6021-2 link deleted due to no data
# WARNING:root:Z6021-4 link deleted due to no data
# WARNING:root:Z6021-5 link deleted due to no data
# WARNING:root:Z6021-6 link deleted due to no data
# WARNING:root:Z6026-1 link deleted due to no data
# WARNING:root:Z6027-1 link deleted due to no data
# WARNING:root:Z6033-1 link deleted due to no data
# WARNING:root:Z6802-2 link deleted due to no data
# WARNING:root:Z6802-4 link deleted due to no data
# WARNING:root:Z6806-2 link deleted due to no data
# WARNING:root:Z6809-1 link deleted due to no data
# WARNING:root:Z6813-2 link deleted due to no data
# WARNING:root:Z6813-4 link deleted due to no data
# WARNING:root:Z6852-2 link deleted due to no data
# WARNING:root:Z6853-2 link deleted due to no data
# WARNING:root:Z6855-2 link deleted due to no data
# WARNING:root:Z6856-1 link deleted due to no data
# WARNING:root:Z7006-1 link deleted due to no data
# WARNING:root:Z7008-2 link deleted due to no data
# WARNING:root:Z7021-2 link deleted due to no data
# WARNING:root:Z7023-2 link deleted due to no data
# WARNING:root:Z7030-1 link deleted due to no data
# WARNING:root:Z7041-1 link deleted due to no data
# WARNING:root:Z7057-2 link deleted due to no data
# WARNING:root:Z7058-1 link deleted due to no data
# WARNING:root:Z7105-1 link deleted due to no data
# WARNING:root:Z7105-2 link deleted due to no data
# WARNING:root:Z7106-2 link deleted due to no data
# WARNING:root:Z7108-2 link deleted due to no data
# WARNING:root:Z7108-4 link deleted due to no data
# WARNING:root:Z7405-1 link deleted due to no data
# WARNING:root:Z7405-2 link deleted due to no data
# WARNING:root:Z7406-1 link deleted due to no data
# WARNING:root:Z7407-1 link deleted due to no data
# WARNING:root:Z7409-1 link deleted due to no data
# WARNING:root:Z7411-1 link deleted due to no data
# WARNING:root:Z7412-1 link deleted due to no data
# WARNING:root:Z7451-1 link deleted due to no data
# WARNING:root:Z7456-2 link deleted due to no data
# WARNING:root:Z7460-1 link deleted due to no data
# WARNING:root:Z7460-2 link deleted due to no data
# WARNING:root:Z7461-1 link deleted due to no data
# WARNING:root:Z7465-1 link deleted due to no data
# WARNING:root:Z7468-1 link deleted due to no data
# WARNING:root:Z7469-1 link deleted due to no data
# WARNING:root:Z7503-1 link deleted due to no data
# WARNING:root:Z7505-2 link deleted due to no data
# WARNING:root:Z7603-1 link deleted due to no data
# WARNING:root:Z7604-1 link deleted due to no data
# WARNING:root:Z7606-1 link deleted due to no data
# WARNING:root:Z7617-1 link deleted due to no data
# WARNING:root:Z7702-3 link deleted due to no data
# WARNING:root:Z7704-2 link deleted due to no data
# WARNING:root:Z7704-4 link deleted due to no data
# WARNING:root:Z7704-5 link deleted due to no data
# WARNING:root:Z7707-1 link deleted due to no data
# WARNING:root:Z7707-2 link deleted due to no data
# WARNING:root:Z7709-1 link deleted due to no data
# WARNING:root:Z7709-2 link deleted due to no data
# WARNING:root:Z7709-4 link deleted due to no data
# WARNING:root:Z7717-2 link deleted due to no data
# WARNING:root:Z8002-2 link deleted due to no data
# WARNING:root:Z8004-2 link deleted due to no data
# WARNING:root:Z8032-1 link deleted due to no data
# WARNING:root:Z8032-2 link deleted due to no data
# WARNING:root:Z8035-1 link deleted due to no data
# WARNING:root:Z8044-2 link deleted due to no data
# WARNING:root:Z8051-1 link deleted due to no data
# WARNING:root:Z8052-2 link deleted due to no data
# WARNING:root:Z8052-5 link deleted due to no data
# WARNING:root:Z8055-1 link deleted due to no data
# WARNING:root:Z8057-1 link deleted due to no data
# WARNING:root:Z8059-1 link deleted due to no data
# WARNING:root:Z8121-1 link deleted due to no data
# WARNING:root:Z8205-1 link deleted due to no data
# WARNING:root:Z8206-2 link deleted due to no data
# WARNING:root:Z8402-2 link deleted due to no data
# WARNING:root:Z8419-1 link deleted due to no data
# WARNING:root:Z8701-1 link deleted due to no data
# WARNING:root:Z8704-1 link deleted due to no data
# WARNING:root:Z8705-1 link deleted due to no data
# WARNING:root:Z8713-1 link deleted due to no data
# WARNING:root:Z8806-1 link deleted due to no data
# WARNING:root:Z8810-1 link deleted due to no data
# WARNING:root:Z8810-2 link deleted due to no data
# WARNING:root:Z8810-4 link deleted due to no data

# %%
#STEP 6 - Get summary of traffic data for all roads
#MAIN BLOCK OF CODE, PART 2: Summary per Road
#this section of code agregates the data from the road segments, to the total road (for each road)

df1 = df #road segment data frame (input), indexed with i
df2 = pd.DataFrame(columns =["Road name","Economic Traffic","No Lanes","Heavy Truck","Medium Truck","Small Truck","Large Bus","Medium Bus","Micro Bus","Utility","Car","Auto Rickshaw","Motor Cycle","Bi-Cycle","Cycle Rickshaw","Cart","Motorized Total","Non Motorized Total","Total Traffic"], index = range(1000))
df2 = df2.fillna(0) #same data frame aggregated to road level (output), indexed with j
j = 0
segment_length = 0
total_length = 0

road_name_previous = 'Na' #initialise for first comparison
for i in range(len(df1)):

#iterating through segments
    segment_length = df1.iloc[i]['Link Length'] #record segment length each time

    road_name_current = df1.iloc[i]['Road name']
    #check if segmnet of road is on a different road i.e. the next road in the df
    if (road_name_current != road_name_previous):
        #divide data by number of segments in the road to get average
        total_length = 0 #reset number of segments for the road
        j = j+1 #update to next row in road_summary dataframe for next road
        df2.iloc[j, df.columns.get_loc('Road name')] = road_name_current
        #set the road name for the row in road_summary
    else:
        total_length += segment_length
    if type(df1.iloc[i]['Economic Traffic'] ) != str:
        #sum the data from this segment to the data already in the summary file for that roads row
        df2.iloc[j, df2.columns.get_loc('No Lanes')] += (df1.iloc[i]['No Lanes'])*segment_length      
        df2.iloc[j, df2.columns.get_loc('Economic Traffic')] += (df1.iloc[i]['Economic Traffic']) *segment_length

        df2.iloc[j, df2.columns.get_loc('Heavy Truck')] += (df1.iloc[i]['Heavy Truck'])*segment_length
        df2.iloc[j, df2.columns.get_loc('Medium Truck')] += (df1.iloc[i]['Medium Truck'])*segment_length
        df2.iloc[j, df2.columns.get_loc('Small Truck')] += (df1.iloc[i]['Small Truck'])*segment_length

        df2.iloc[j, df2.columns.get_loc('Large Bus')] += (df1.iloc[i]['Large Bus'])*segment_length
        df2.iloc[j, df2.columns.get_loc('Medium Bus')] += (df1.iloc[i]['Medium Bus'])*segment_length
        df2.iloc[j, df2.columns.get_loc('Micro Bus')] += (df1.iloc[i]['Micro Bus'])*segment_length

        df2.iloc[j, df2.columns.get_loc('Utility')] += (df1.iloc[i]['Utility'])*segment_length
                    
        df2.iloc[j, df2.columns.get_loc('Car')] += (df1.iloc[i]['Car'])*segment_length
        df2.iloc[j, df2.columns.get_loc('Auto Rickshaw')] += (df1.iloc[i]['Auto Rickshaw'])*segment_length
        df2.iloc[j, df2.columns.get_loc('Motor Cycle')] += (df1.iloc[i]['Motor Cycle'])*segment_length
        df2.iloc[j, df2.columns.get_loc('Bi-Cycle')] += (df1.iloc[i]['Bi-Cycle'])*segment_length      
        df2.iloc[j, df2.columns.get_loc('Cycle Rickshaw')] += (df1.iloc[i]['Cycle Rickshaw'])*segment_length
        df2.iloc[j, df2.columns.get_loc('Cart')] += (df1.iloc[i]['Cart'])*segment_length
                    
        df2.iloc[j, df2.columns.get_loc('Motorized Total')] += (df1.iloc[i]['Motorized Total'])*segment_length    
        df2.iloc[j, df2.columns.get_loc('Non Motorized Total')] += (df1.iloc[i]['Non Motorized Total'])*segment_length      
        df2.iloc[j, df2.columns.get_loc('Total Traffic')] += (df1.iloc[i]['Total Traffic'])*segment_length       

    
    #pass into memory for next comparison
    road_name_previous = road_name_current 
    
#save output file
df2.to_csv('summary_data_traffic_per_road.csv',sep= ',', header=True)

# %%
#STEP 7 - Renaming / framing dataframes
df_traffic = df

#create empty float colums for summing average delay time & delete prerome points from previous assignment
df_all_bmms["average_delay"] = np.nan

#rename some columns in the traffic data for panda operations
df_traffic = df_traffic.rename(columns={'Total Traffic': 'Total_Traffic','Economic Traffic': 'Economic_Traffic','End Chainage': 'End_Chainage', 'No Lanes': 'No_Lanes','Start Chainage': 'Start_Chainage','Link no': 'Link_No','Link Name':'Link_Name',"Link Length": "Link_Length","Road name":"Road_Name"})

# %%
#STEP 8 - fix some of the missing data for segments (90 segments did not allign --> see report)
for row in range(len(df_traffic)):
    if row > 0: 
        if df_traffic.Road_Name.iloc[row-1,] == df_traffic.Road_Name.iloc[row,]:
            preceding_segment_end_chainage = df_traffic.End_Chainage.iloc[row-1,]
            if df_traffic.End_Chainage.iloc[row-1,] != df_traffic.Start_Chainage.iloc[row,]:
                df_traffic.Start_Chainage.iloc[row,] = preceding_segment_end_chainage

# %%
#STEP 9 - CHECK THE DATA CLEANING SCRIPT FOR MISSING SEGMENTS --> no non alligned segments should be present
df_traffic["missing_segment"] = ""
for row in range(len(df_traffic)):
    if row > 0:
        if df_traffic.Road_Name.iloc[row-1,] == df_traffic.Road_Name.iloc[row,]:
            if df_traffic.End_Chainage.iloc[row-1,] != df_traffic.Start_Chainage.iloc[row,]:
                df_traffic.missing_segment.iloc[row,] = True
df_traffic[df_traffic["missing_segment"] == True]
# Out:
#      Road_Name  Link_No                                          Link_Name  \
# 107       N102   N102-4  Companiganj (Int with Z1205) - Mirpur (Int wit...
# 117       N104   N104-4  Selonia(Int.with Z1443)-Daganbhuiyan (Int.with...
# 127       N105   N105-4          Purbachal Road- Ulukhola (Int.with Z3010)
# 133       N106   N106-4  Munshihat (Int.with Z1629)-Raozan (Int.with Z1...
# 162         N2     N2-4      Bhulta (Int.with R202)-Bhulta (Int.with R203)
# 195       N207   N207-4                Moulvibazar (Int.with N208)-Sherpur
# 198       N208   N208-4  Daudabad (Int.with Z2832)-Royal City Chottor(i...
# 245       N302   N302-4     Ashulia(Int.with N511)-Zerabo (Int.with Z3007)
# 252         N4     N4-4    Kaliakoir (Int.with R315)-Gorai(Int.with Z4011)
# 268       N401   N401-4  Mymensingh engineering College(Int.withN309)-M...
# 276       N405   N405-4                   Nalka (Int.with R451)-Hatikamrul
# 322         N5    N5-38               Mohasthangar Z5505-Chowkirghat Z5072
# 356       N502   N502-4  Omarpur (Nandigram) Int.with Z5202-Int.with Z5...
# 364       N506   N506-4                  Barabari (Int.with N509)-Kurigram
# 367       N507   N507-4           Int.with Z5209-Laxmikul (Int.with Z6015)
# 373       N509   N509-4  Barakhata(Int.with R560)-Patgram Bypass (Int.w...
# 399         N6     N6-4  Madhpur(Int. with Z6026)-Atikula (Int. with Z6...
# 433         N7     N7-4  Ahladipur, Int.with R710-Goalchamot (Faridpur)...
# 471       N704   N704-4  Shekhpara(Int.with Z7405)-Bottoli More (Kushti...
# 495       N712   N712-4                     Int with N703-Alhera bus Stand
# 500         N8     N8-4          Int. with N802- Baorvita (Int.with Z5069)
# 533       N803   N803-3                           (Int.with Z7108)-SS Ghat
# 536       N804   N804-4  Munshipara (Int. with N808) -Faridpur (Alipur)...
# 540       N805   N805-4  Garakhola(Int.with Z8023)-Bhatiapara (Int.with...
# 556       N806   N806-4                   Simakhali(Int.with Z7505)-Narail
# 564       N809   N809-3       Dinerpool (Int.with Z8044)-Veduria Ferryghat
# 571       R110   R110-4  Konapara (int with R201) - Shimrail (int with N1)
# 579       R114   R114-4  Shahepratap (int with R210) - Raipur (road end...
# 583       R140   R140-4      Lalmai(Int.with R141)-Mogbari(int.with Z1401)
# 605       R141   R141-2            Bagmara (Int.with Z1049-Int.with Z1049)
# ...        ...      ...                                                ...
# 850       R685   R685-4  Mohonpur, Sahipara(Int.with Z6853)-Manda (Int....
# 854       R710   R710-4    Tottipur(int.with R712)-Khoksha(Int.with Z7105)
# 864       R745   R745-4    Bamundi (int.with Z7456)-Gangni(int.with Z7452)
# 880       R748   R748-4  Kotchandpur(int.with Z7024)-Chandpara (int.wit...
# 885       R755   R755-4  Keshabpur (int.with Z7553)-Chuknagar (int.with...
# 892       R770   R770-4  Signboard (Int.with Z7702)-Pirojpur (Bus Stand...
# 903       R812   R812-4                      Hatimara(Int.with Z8004)-Mawa
# 909       R820   R820-4  Kharsur (Int.with Z8003)-Tikarpur(int.with Z8204)
# 918       R850   R850-4                  Borashi (Int.with Z8408)-Mollahat
# 922       R860   R860-4  Kazirtek(Int.with Z8611)-Monohorpur(int.with R...
# 929       R870   R870-4    (Int with Z8702) Rajapur - Int Z8705, Bhandaria
# 936       R880   R880-4  Amtali (Int with R880)-Barguna Bus Stand (Int ...
# 941       R890   R890-4  Kungerhat(int.with Z8943)-Lalmohon(int.with Z8...
# 993      Z1039  Z1039-1                            Patiya-(int.with Z1036)
# 996      Z1040  Z1040-4             Int.with Z1070-Anowara (int.with R170)
# 1153     Z1603  Z1603-4                   Baghaihat (Int.with Z1606)-Sajek
# 1354     Z5002  Z5002-5                  Bokultala(int.with Z5006)-Birganj
# 1381     Z5025  Z5025-4  Badarganj(int.with R557)-Laldighi(int.with Z5015)
# 1446     Z5401  Z5401-4                          Pipulbaria More-Sonamukhi
# 1549     Z6006  Z6006-4   Lalpur(int.with Z6014)-Ishwardi (Int.with Z6022)
# 1586     Z6802  Z6802-5                Rohonpur(int.with R547) -Bhangabari
# 1598     Z6813  Z6813-5                 Dhansura(int.with Z6812)-Niamatpur
# 1722     Z7702  Z7702-4                        Morelganj (CARE Bazar)-Bogi
# 1759     Z8031  Z8031-4                      Int with Z8049-Int with Z8032
# 1765     Z8033  Z8033-4                              Banaripara-Swarupkati
# 1786     Z8052  Z8052-4  Mirzaganj (int.with Z8810)- Patuakhali Chouras...
# 1845     Z8702  Z8702-4   Bekutia Ferryghat West-Pirojpur (Fishig Complex)
# 1851     Z8705  Z8705-4                Bandakada(int.with Z8740)-Kanthalia
# 1855     Z8708  Z8708-4   Kachua(int.with Z8052)-Kanthalia(int.with Z8705)
# 1872     Z8806  Z8806-4  Kalaiya (Int.with Z8052)-Amragachia(int.with R...
#
#      Start LRP Start Offset  Start_Chainage End LRP End Offset  End_Chainage  \
# 107     LRP024         1242          25.473  LRP038        408        38.866
# 117     LRP008          485           8.315  LRP014        994        14.809
# 127    LRP020d            0          21.221  LRP028        895        28.610
# 133     LRP024          828          24.297  LRP025        820        25.278
# 162     LRP011          915          11.111  LRP011       1781        11.977
# 195     LRP043           12          42.917    LRPE          0        67.985
# 198     LRP052          385          51.050  LRP054        677        53.342
# 245     LRP008          757           8.730  LRP008       3397        11.370
# 252     LRP022          148          20.864  LRP027        492        26.218
# 268     LRP040           18          40.043    LRPE          0        46.980
# 276     LRP036          409          36.144  LRP040        945        40.780
# 322     LRP232          940         233.530  LRP234       4873       239.463
# 356     LRP026          558          25.578  LRP040       4670        43.700
# 364     LRP033         1027          32.904    LRPE          0        50.017
# 367     LRP028          930          28.110  LRP043       1130        43.330
# 373     LRP071         2980          72.970  LRP091       1193        90.973
# 399     LRP021         1627          22.609  LRP024       1548        25.524
# 433     LRP013          780          13.780  LRP028       1500        29.540
# 471     LRP021          292          21.187  LRP041        344        41.222
# 495     LRP002         3150           5.150    LRPE          0         6.150
# 500    LRP004c            0           4.748  LRP010        475        10.675
# 533       LRPS         4550           4.550    LRPE          0         6.130
# 536     LRP026          270          25.348  LRP026       4682        29.760
# 540     LRP024          750          24.590  LRP037        135        37.005
# 556     LRP019         1466          21.235  LRP021       1000        22.769
# 564     LRP003         2300           5.300  LRP025        675        25.690
# 571     LRP006          820           6.300  LRP006       4710        10.190
# 579     LRP027          131          25.920  LRP029      26774        54.782
# 583     LRP011         1192          12.342  LRP011       2065        13.215
# 605       LRPS         1978           1.978    LRPS       2280         2.280
# ...        ...          ...             ...     ...        ...           ...
# 850     LRP024         1000          24.120  LRP049        210        48.535
# 854     LRP042          740          42.510  LRP047        850        47.650
# 864     LRP030         1080          29.869  LRP041        775        40.569
# 880     LRP052          567          52.642  LRP058        935        58.990
# 885     LRP027          346          26.752    LRPE          0        38.265
# 892     LRP027           16          26.466  LRP041        275        41.075
# 903     LRP014          845          13.220    LRPE          0        42.285
# 909     LRP019         2721          21.711  LRP024       2578        26.016
# 918     LRP039          580          38.460    LRPE          0        44.830
# 922     LRP012          133          12.561  LRP016       6126        22.531
# 929     LRP029         1207          29.935  LRP044        298        43.972
# 936     LRP029          873          29.138  LRP043        948        43.021
# 941     LRP041          320          41.620  LRP052        610        53.040
# 993       LRPS            0           0.000    LRPS      13362        13.362
# 996    LRP012a          170          12.600    LRPE          0        16.480
# 1153    LRP026         1550          28.055    LRPE          0        65.254
# 1354    LRP061         1275          62.215  LRP077       1980        78.670
# 1381    LRP023         2300          23.956  LRP030        140        28.896
# 1446    LRP013          388          12.400  LRP035       2383        36.395
# 1549    LRP040          639          40.903    LRPE          0        53.362
# 1586    LRP024          380          22.870    LRPE          0        34.610
# 1598    LRP044           90          42.920    LRPE          0        59.950
# 1722    LRP024         3040          25.988  LRP053        202        52.039
# 1759    LRP006         4081           9.907  LRP020       5622        24.971
# 1765    LRP018           90          18.090  LRP026        990        26.840
# 1786    LRP015          596          15.389  LRP025        730        25.993
# 1845    LRP012         1526          12.466  LRP012       3700        14.648
# 1851    LRP007         2960          10.000  LRP011        815        11.885
# 1855      LRPS        18680          18.680    LRPS      22978        22.978
# 1872    LRP027         2140          28.656    LRPE          0        86.377
#
#       Link_Length       ...            Car Auto Rickshaw Motor Cycle Bi-Cycle  \
# 107        13.393       ...         116.15       1269.61      242.86  62.3492
# ...            ...             ...
# 850        2229.24            True
# 854         3429.5            True
# 864         3506.5            True
# 880           1836            True
# 885        2401.27            True
# 892         2713.5            True
# 903        1548.56            True
# 909           2770            True
# 918        3598.67            True
# 922        1429.41            True
# 929        2247.21            True
# 936        5547.78            True
# 941           2238            True
# 993            866            True
# 996        2378.67            True
# 1153          6862            True
# 1354       672.484            True
# 1381          3748            True
# 1446          2953            True
# 1549       3875.61            True
# 1586       3652.44            True
# 1598       3539.58            True
# 1722       2914.14            True
# 1759       1625.73            True
# 1765       1537.95            True
# 1786       3378.32            True
# 1845          1136            True
# 1851           999            True
# 1855       1165.06            True
# 1872       888.015            True
#
# [89 rows x 29 columns]

# %%
#STEP 10 - RUN THIS LINE OF CODE FOR LINKING THE ROAD DATA WITH THE TRAFFIC (PER SEGMENT DATA) USING THE LINK NUMBER (lINK_NO)
df_selected = df_all_bmms
df_selected["Road_segment_no"] =""
df_selected["Road_segment_label"] =""

for row_number in range(len(df_selected)):
    chainage = df_selected.chainage.iloc[row_number,]
    road_number = df_selected.road.iloc[row_number,]
    
    all_segments_in_road_df = df_traffic[df_traffic["Road_Name"] == road_number ]
    
    for segments in range(len(all_segments_in_road_df)):
        segment_start_chainage = all_segments_in_road_df.Start_Chainage.iloc[segments,]
        segment_end_chainage = all_segments_in_road_df.End_Chainage.iloc[segments,]
        segment_no = all_segments_in_road_df.Link_No.iloc[segments,]
        segment_label = all_segments_in_road_df.Link_Name.iloc[segments,]
                    
        if chainage >= segment_start_chainage:
            if chainage < segment_end_chainage:       
                df_selected.Road_segment_no.loc[row_number,] = segment_no
                df_selected.Road_segment_label.loc[row_number,] = segment_label    

df_BMSS_traffic_link = df_selected

# %%
#STEP 11 - CHECK HOW MUCH MISSING DATA IS THERE
#3305 bridges mis segment data to this point
number_of_missing_bridges_without_segment_data = (df_BMSS_traffic_link['Road_segment_no'].values == '').sum()
Missing_segment_data_brigdes_df = df_BMSS_traffic_link[df_BMSS_traffic_link['Road_segment_no'] == '']

#The missing bridges are mostly on Z roads -> impact on system results should not be that high and there is also often no traffic data for those roads
list_of_road_with_missing_segment_data = Missing_segment_data_brigdes_df.road.unique()

#drop the missing segments
df_BMSS_traffic_link = df_BMSS_traffic_link[df_BMSS_traffic_link["Road_segment_no"] != '']

# %%
#STEP 12 - Determine vulnerability of bridges based on their scenario likelihood --> SEE REPORT FOR EXPLANATION
scenario = {'Scenario': [1,2,3,4,5,6,7,8], 'A': [0,0,0,0,0,0,0.05,0.10], 
            'B': [0,0,0,0,0.05,0.10,0.10,0.20],'C':[0,0,0.05,0.10,0.10,0.20,0.20,0.40],'D':[0,0.05,0.10,0.20,0.20,0.40,0.40,0.80],
            'Scenario_likelihood': [0.222,0.194,0.167,0.139,0.111,0.083,0.056,0.028]}

scenario_df = pd.DataFrame(data=scenario)
scenario_df = scenario_df.drop(scenario_df.index[0])

scenario_df["A_overall"] = scenario_df.Scenario_likelihood *scenario_df.A
scenario_df["B_overall"] = scenario_df.Scenario_likelihood *scenario_df.B
scenario_df["C_overall"] = scenario_df.Scenario_likelihood *scenario_df.C
scenario_df["D_overall"] = scenario_df.Scenario_likelihood *scenario_df.D

sum_row = {col: scenario_df[col].sum() for col in scenario_df}
scenario_df_sum = pd.DataFrame(sum_row, index=["Total"])
scenario_df = scenario_df.append(scenario_df_sum)
#---------> A_overall total is vulnerability of bridge

# %%
#STEP 13 - RUN THIS LINE OF CODE FOR CALCULATING THE VULNERABILITY OF EACH ROAD SEGMENT IN THE TRAFFIC DATA FILE
#add coumns to df_traffic for output of vulnerability data
df_traffic["Total_A"] = ""
df_traffic["Total_B"] = ""
df_traffic["Total_C"] = ""
df_traffic["Total_D"] = ""
df_traffic["segment_vulnerability"] = ""
df_traffic["segment_vulnerability_length"] = ""

#iterate through all segments in the traffic file to get the vulnerability per segment
for i in range(len(df_traffic)):
    segment_name = df_traffic.iloc[i]['Link_No']
    
    #make small dataframe to get all bridges on that segment
    df_segments = df_BMSS_traffic_link[df_BMSS_traffic_link["Road_segment_no"] == segment_name]
    Bridge_count = df_segments.groupby(["condition"]).count()
    
    #create series object to count the bridges
    Bridge_count = Bridge_count["road"]
    categories = Bridge_count.index.values.tolist()
    
    #count number of bridges per category and check if they are they are there
    if 'A' in categories:
        total_A_Bridges = Bridge_count['A']
    else:
        total_A_Bridges = 0
    if 'B' in categories:
        total_B_Bridges = Bridge_count['B']
    else:
        total_B_Bridges = 0
    if 'C' in categories:
        total_C_Bridges = Bridge_count['C']
    else:
        total_C_Bridges = 0
    if 'D' in categories:
        total_D_Bridges = Bridge_count['D']
    else:
        total_D_Bridges = 0 
    
    #determine segment vulnerability based on scenario likehood and number of bridges on that segment
    segment_vulnerability = total_A_Bridges * scenario_df.iloc[7]['A_overall'] + total_B_Bridges * scenario_df.iloc[7]['B_overall'] + total_C_Bridges * scenario_df.iloc[7]['C_overall'] + total_D_Bridges * scenario_df.iloc[7]['D_overall'] 
        
    #store total bridges in segment traffic file    
    df_traffic.iloc[i, df_traffic.columns.get_loc('Total_A')] = total_A_Bridges
    df_traffic.iloc[i, df_traffic.columns.get_loc('Total_B')] = total_B_Bridges
    df_traffic.iloc[i, df_traffic.columns.get_loc('Total_C')] = total_C_Bridges
    df_traffic.iloc[i, df_traffic.columns.get_loc('Total_D')] = total_D_Bridges
    
    #store vulnerability in segment traffic file    
    df_traffic.iloc[i, df_traffic.columns.get_loc('segment_vulnerability')] = segment_vulnerability

# %%
#STEP 14 - NORMALIZING vulnerability & Criticality
max_vul = df_traffic.segment_vulnerability.max()
min_vul = df_traffic.segment_vulnerability.min()
max_cri = df_traffic.Economic_Traffic.max()
min_cri = df_traffic.Economic_Traffic.min()
#scaling the values on a scale from 0 to 1
df_traffic['segment_vulnerability_normalized'] = (df_traffic.segment_vulnerability - min_vul) / max_vul
df_traffic['Economic_Traffic_normalized'] = (df_traffic.Economic_Traffic - min_cri) / max_cri

df_traffic
# Out:
#      Road_Name  Link_No                                          Link_Name  \
# 0           N1     N1-1           Jatrabari - Int.with Z1101 (Left) (Left)
# 2           N1    N1-2R     Int.with Z1101 - Signboard (Left) R111 (Right)
# 3           N1     N1-3             Signboard - Shimrail (Left)R110 (Left)
# 5           N1     N1-4                Shimrail - Katchpur (Left)N2 (Left)
# 7           N1     N1-5              Katchpur - Madanpur (Left)N105 (Left)
# 9           N1     N1-6           Madanpur - Langalband (Left)Z1061 (Left)
# 11          N1     N1-7  Langalband - Mograpara Chowrasta (Left)Z1089 (...
# 13          N1     N1-8  Mograpara(Int.with Z1089)-Meghna Bridge West E...
# 15          N1     N1-9  Meghna Bridge Satrt-Bhaberchar (Left) z1063 (L...
# 17          N1    N1-10  Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...
# 19          N1    N1-11           Daudkandi Bridge- Daudkandi Z1062 (Left)
# 21          N1    N1-12              Daudkandi Z1062 - Pennai Z1053 (Left)
# 23          N1    N1-13     Pennai Z1053- Gouripur (Int.with Z1044) (Left)
# 25          N1    N1-14  Gouripur (Int.with Z1044) - Eliotganj Z1042 (L...
# 27          N1    N1-15              Eliotganj Z1042- Madhaya Z1017 (Left)
# 29          N1    N1-16              Madhaya Z1017 - Chandina Z1022 (Left)
# 31          N1    N1-17  Chandina Z1022 - Nimsar (Int.with Z1219 & Z102...
# 33          N1    N1-18  Nimsar (Int.with Z1219 & Z1028) - Mainamati N1...
# 35          N1    N1-19              Mainamati N102- Int.with Z1029 (Left)
# 37          N1    N1-20             Int.with Z1029 - Int.with Z1052 (Left)
# 39          N1    N1-21         Int.with Z1052 - Changani (Kotbari) (Left)
# 41          N1    N1-22  Changani (Kotbari) - Paduar Bazar Biswa Rd. R1...
# 43          N1    N1-23  Paduar Bazar Biswa Rd. R140 - Miabazar Z1046 (...
# 45          N1    N1-24  Miabazar Z1046 - Chauddagram(Int.with Z1045) (...
# 47          N1    N1-25  Chauddagram(Int.with Z1045)-Md. Ali bazar (Int...
# 49          N1    N1-26  Md. Ali bazar (Int.with Z1031)-Int.with Z1031 ...
# 51          N1    N1-27     Int.with Z1031 - Elahiganj (Feni) Z1030 (Left)
# 53          N1    N1-28  Elahiganj (Feni) Z1030- Feni (Int.with N104) (...
# 55          N1    N1-29  Feni (Int.with N104) - Feni Shahid Minar (Int....
# 57          N1    N1-30  Feni Shahid Minar( Int.with Z1034)-Fazilpur (Z...
# ...        ...      ...                                                ...
# 1855     Z8708  Z8708-4   Kachua(int.with Z8052)-Kanthalia(int.with Z8705)
# 1856     Z8708  Z8708-5           Kanthalia(int.with Z8705)-Amua Ferryghat
# 1857     Z8708  Z8708-6                      Amua Ferryghat-Int.with Z8814
# 1858     Z8708  Z8708-7                            Int.with Z8814-Kacchira
# 1859     Z8708  Z8708-8                               Kacchira-Patharghata
# 1860     Z8709  Z8709-1                        Satpakhia-Ferryghat (North)
# 1862     Z8713  Z8713-2                Chirapara(int.with Z8702)-Bhandaria
# 1863     Z8716  Z8716-1              Jhalokathi (College More)-Swarupkathi
# 1864     Z8717  Z8717-1                                  Naikati-Bhandaria
# 1865     Z8740  Z8740-1               Bandaghata-Banaihat (Int.with Z8711)
